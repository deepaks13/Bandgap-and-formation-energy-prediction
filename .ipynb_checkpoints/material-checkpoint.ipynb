# %%
import pandas as pd
from sklearn import preprocessing

# %%
df= pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    id  spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 0   1          33                   80.0           0.6250           0.3750
# 1   2         194                   80.0           0.6250           0.3750
# 2   3         227                   40.0           0.8125           0.1875
# 3   4         167                   30.0           0.7500           0.0000
# 4   5         194                   80.0           0.0000           0.6250
#
#    percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 0            0.000                9.9523                8.5513
# 1            0.000                6.1840                6.1838
# 2            0.000                9.7510                5.6595
# 3            0.250                5.0036                5.0034
# 4            0.375                6.6614                6.6612
#
#    lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 0                9.1775                     90.0026
# 1               23.6287                     90.0186
# 2               13.9630                     90.9688
# 3               13.5318                     89.9888
# 4               24.5813                     89.9960
#
#    lattice_angle_beta_degree  lattice_angle_gamma_degree  \
# 0                    90.0023                     90.0017
# 1                    89.9980                    120.0025
# 2                    91.1228                     30.5185
# 3                    90.0119                    120.0017
# 4                    90.0006                    119.9893
#
#    formation_energy_ev_natom  bandgap_energy_ev
# 0                     0.0680             3.4387
# 1                     0.2490             2.9210
# 2                     0.1821             2.7438
# 3                     0.2172             3.3492
# 4                     0.0505             1.3793

# %%
db=df.drop(['id','formation_energy_ev_natom'],axis=1)

# %%
db.head()
# Out:
#    spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 0          33                   80.0           0.6250           0.3750
# 1         194                   80.0           0.6250           0.3750
# 2         227                   40.0           0.8125           0.1875
# 3         167                   30.0           0.7500           0.0000
# 4         194                   80.0           0.0000           0.6250
#
#    percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 0            0.000                9.9523                8.5513
# 1            0.000                6.1840                6.1838
# 2            0.000                9.7510                5.6595
# 3            0.250                5.0036                5.0034
# 4            0.375                6.6614                6.6612
#
#    lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 0                9.1775                     90.0026
# 1               23.6287                     90.0186
# 2               13.9630                     90.9688
# 3               13.5318                     89.9888
# 4               24.5813                     89.9960
#
#    lattice_angle_beta_degree  lattice_angle_gamma_degree  bandgap_energy_ev
# 0                    90.0023                     90.0017             3.4387
# 1                    89.9980                    120.0025             2.9210
# 2                    91.1228                     30.5185             2.7438
# 3                    90.0119                    120.0017             3.3492
# 4                    90.0006                    119.9893             1.3793

# %%
x=db.iloc[:,:-1].values
y=db.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
xb_train, xb_test, yb_train, yb_test = train_test_split( x, y, test_size=0.20, random_state=42)

# %%
x
# Out:
# array([[ 33.    ,  80.    ,   0.625 , ...,  90.0026,  90.0023,  90.0017],
#        [194.    ,  80.    ,   0.625 , ...,  90.0186,  89.998 , 120.0025],
#        [227.    ,  40.    ,   0.8125, ...,  90.9688,  91.1228,  30.5185],
#        ...,
#        [206.    ,  80.    ,   0.4375, ...,  90.0047,  90.0046,  89.9954],
#        [ 33.    ,  80.    ,   0.3125, ...,  90.0015,  89.9996,  90.0004],
#        [206.    ,  80.    ,   0.875 , ...,  90.0027,  90.0037,  89.9987]])

# %%
X=db.drop('bandgap_energy_ev',axis=1)

# %%
Y=db['bandgap_energy_ev']

# %%
from sklearn.model_selection import train_test_split
Xb_train, Xb_test, Yb_train, Yb_test = train_test_split( X, Y, test_size=0.20, random_state=42)

# %%
Xb_train
# Out:
#       spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 120          227                   40.0           0.5000           0.1875
# 283          167                   30.0           0.4167           0.5833
# 1727         206                   80.0           0.7188           0.2812
# 1984         194                   80.0           0.0000           0.8750
# 647           33                   80.0           0.6875           0.2812
# ...          ...                    ...              ...              ...
# 1638          12                   80.0           0.0938           0.5625
# 1095         194                   80.0           0.1875           0.2812
# 1130          33                   40.0           0.0625           0.0000
# 1294          12                   20.0           0.3750           0.3750
# 860           33                   80.0           0.6875           0.1250
#
#       percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 120            0.3125                5.9907                5.9905
# 283            0.0000                4.9566                4.9562
# 1727           0.0000                9.1025                9.1019
# 1984           0.1250                6.4775                6.4775
# 647            0.0312                9.9577                8.5526
# ...               ...                   ...                   ...
# 1638           0.3438               24.7335                6.3348
# 1095           0.5312                6.7148                6.7144
# 1130           0.9375                5.6276                9.5622
# 1294           0.2500               12.2329                3.1012
# 860            0.1875               10.1310                8.6837
#
#       lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 120                14.6544                     89.9923
# 283                13.4178                     89.9938
# 1727                9.1021                     90.0035
# 1984               24.2597                     89.9951
# 647                 9.1802                     90.0033
# ...                    ...                         ...
# 1638                6.2101                     90.0001
# 1095               24.6411                     90.0098
# 1130               10.1876                     90.0004
# 1294                6.0565                     89.9998
# 860                 9.3127                     90.0040
#
#       lattice_angle_beta_degree  lattice_angle_gamma_degree
# 120                     90.0076                    119.9949
# 283                     90.0075                    120.0007
# 1727                    90.0041                     89.9974
# 1984                    90.0067                    119.9924
# 647                     90.0022                     90.0015
# ...                         ...                         ...
# 1638                   104.6430                     90.0001
# 1095                    90.0005                    119.9896
# 1130                    89.9960                     90.0004
# 1294                   104.4912                     90.0001
# 860                     90.0017                     90.0010
#
# [1920 rows x 11 columns]

# %%
Xb_train.spacegroup.value_counts().to_dict()
# Out:
# {206: 385, 33: 356, 227: 316, 167: 299, 12: 284, 194: 280}

# %%
frequency_map = Xb_train.spacegroup.value_counts().to_dict()
Xb_train.spacegroup = Xb_train.spacegroup.map(frequency_map )
# Out:
# C:\Users\Mypc\Anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
Xb_test.spacegroup = Xb_test.spacegroup.map(frequency_map )

# %%
Xb_test
# Out:
#       spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 2037         299                   30.0           0.0000           0.6667
# 1978         385                   80.0           0.3438           0.3750
# 855          356                   40.0           0.7500           0.2500
# 1719         316                   40.0           0.9375           0.0625
# 2019         316                   40.0           0.8125           0.1875
# ...          ...                    ...              ...              ...
# 1832         284                   80.0           0.2812           0.3125
# 203          280                   80.0           0.0312           0.4688
# 174          385                   80.0           0.0938           0.0625
# 420          284                   80.0           0.3438           0.2812
# 892          316                   40.0           0.5000           0.1875
#
#       percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 2037           0.3333                5.2326                5.2320
# 1978           0.2812                9.5090                9.5087
# 855            0.0000                4.9469                8.5014
# 1719           0.0000                5.6994                5.6995
# 2019           0.0000                9.8390                5.6764
# ...               ...                   ...                   ...
# 1832           0.4062               24.5221                6.3164
# 203            0.5000                6.7431                6.7427
# 174            0.8438               10.1125               10.1124
# 420            0.3750               24.4654                6.2812
# 892            0.3125                9.8692                5.7321
#
#       lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 2037               13.9994                     90.0004
# 1978                9.5087                     90.0031
# 855                 9.1298                     90.0038
# 1719               13.9860                     90.0080
# 2019               13.8993                     92.1548
# ...                    ...                         ...
# 1832                6.2360                     89.9999
# 203                24.7186                     90.0005
# 174                10.1127                     90.0008
# 420                 6.1912                     89.9998
# 892                14.1649                     91.1614
#
#       lattice_angle_beta_degree  lattice_angle_gamma_degree
# 2037                    89.9997                    120.0003
# 1978                    90.0032                     89.9967
# 855                     90.0023                     90.0015
# 1719                    89.9898                    120.0040
# 2019                    92.0238                     30.1576
# ...                         ...                         ...
# 1832                   104.8685                     90.0001
# 203                     89.9974                    119.9883
# 174                     90.0009                     89.9989
# 420                    104.8096                     90.0001
# 892                     91.3477                     30.5865
#
# [480 rows x 11 columns]

# %%
scaler = preprocessing.StandardScaler().fit(Xb_train)
Xb_train = scaler.transform(Xb_train)
Xb_test=scaler.transform(Xb_test)

# %%
Xb_test
# Out:
# array([[-0.64819159, -1.39398458, -1.46347976, ..., -0.17685232,
#         -0.44862803,  0.97447887],
#        [ 1.52746795,  0.81686161, -0.16807251, ..., -0.17486101,
#         -0.44796655, -0.19006179],
#        [ 0.79381532, -0.95181534,  1.3624523 , ..., -0.17434474,
#         -0.44813665, -0.18987548],
#        ...,
#        [ 1.52746795,  0.81686161, -1.11004986, ..., -0.17655731,
#         -0.44840124, -0.1899764 ],
#        [-1.02766709,  0.81686161, -0.16807251, ..., -0.17729484,
#          2.35036442, -0.18992982],
#        [-0.21811936, -0.95181534,  0.42047495, ...,  0.67941295,
#         -0.19386319, -2.49597154]])
